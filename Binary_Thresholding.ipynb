# %%
# !pip install pytesseract pillow
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.2)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
# !apt-get install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (25.6 MB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import os
import cv2
import pytesseract
from PIL import Image

# Set the path to Tesseract OCR executable
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# Paths
image_folder = "/content/invoice/images"
output_folder = "/content/extracted_texts/"  # Folder to save .txt files

# Function to extract text using Tesseract
def extract_text(image_path):
    """
    Convert an image to text using Tesseract OCR.

    Args:
        image_path (str): Path to the image file.

    Returns:
        str: Extracted text from the image.
    """
    try:
        # Open the image file
        img = Image.open(image_path)

        # Perform OCR
        text = pytesseract.image_to_string(img)

        return text
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return ""

# Function to preprocess the image with thresholding (no resizing)
def preprocess_image(image_path):
    """
    Preprocess the image: apply binary threshold without resizing.

    Args:
        image_path (str): Path to the image file.

    Returns:
        str: Path to the preprocessed image file.
    """
    try:
        # Load the image in grayscale mode
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        if img is None:
            print(f"Error: Unable to load image {image_path}")
            return None

        # Apply binary thresholding
        _, thresholded_img = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)

        # Save the preprocessed image to a temporary file
        preprocessed_image_path = os.path.splitext(image_path)[0] + "_thresholded.jpg"
        cv2.imwrite(preprocessed_image_path, thresholded_img)

        return preprocessed_image_path
    except Exception as e:
        print(f"Error preprocessing image {image_path}: {e}")
        return None

# Function to process the dataset (folder of images)
def process_dataset(image_folder, output_folder):
    # Check if the output folder exists, create it if not
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Counter to limit the number of processed images


    # Loop through all files in the folder
    for filename in os.listdir(image_folder):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
            # Construct the full image path
            image_path = os.path.join(image_folder, filename)

            # Extract text from the original image
            print(f"Processing original image: {filename}")
            original_text = extract_text(image_path)
            print("Text from original image:")
            print(original_text)

            # Preprocess the image (threshold only)
            preprocessed_image_path = preprocess_image(image_path)

            if preprocessed_image_path:
                # Extract text from the preprocessed image
                print(f"Processing preprocessed image: {os.path.basename(preprocessed_image_path)}")
                preprocessed_text = extract_text(preprocessed_image_path)
                print("Text from preprocessed image:")
                print(preprocessed_text)

                # Create output .txt file path
                txt_filename = os.path.splitext(filename)[0] + "_preprocessed.txt"
                output_txt_path = os.path.join(output_folder, txt_filename)

                # Save extracted text from preprocessed image to .txt file
                try:
                    with open(output_txt_path, 'w') as txt_file:
                        txt_file.write(preprocessed_text)
                    print(f"Processed {filename}, saved text to {txt_filename}")
                except Exception as e:
                    print(f"Error saving text for {filename}: {e}")

            # Increment the counter and stop if limit is reached


# Call the function to process the dataset
process_dataset(image_folder, output_folder)
# Out:
# Processing original image: Template9_Instance170_resized.jpg
# Text from original image:
# Navarro, Ford and Bryan INVOICE # INV/73-81/333
#
# Invoice Date: 06-Jun-2012
# GSTIN/UIN: O9AABCS142961ZS
#
# Email:rclark@example.org
#
# Buyer :Alan Poole
#
# 515 Suzanne Dam Suite 983
# Brittanyside, OH 05404 US
# Tel:+(141)371-7288
# Email:martinezanna@example.com
# Site:https://reilly-howell.biz/
#
# | Oty | Description | Unit Price _| Amount
# 5.00 _Two drug data. | 46.98 | 234.90
# 2.00 _Mission federal my. | 1.67 | 15.34
# _ 3.00 _ Defense participant until. | 56.41 | 169.23
# 5.00 _ Evidence produce. I 12.39 | 61.95
#
# Total in words: four hundred and ninet-
# y-eight point zero two
#
# TOTAL : 498.02 EUR
#
# Note:Total payment due in 14 days.
#
# Processing preprocessed image: Template9_Instance170_resized_thresholded.jpg
# Text from preprocessed image:
# Navarro, Ford and Bryan INVOICE # INV/73-81/333
#
# GSTIN/UIN: 09AABCS142961ZS
#
# Email:rclark@example.org
#
# Buyer :Alan Poole
#
# 515 Suzanne Dam Suite 983
# Brittanyside, OH 05404 US
# Tel:+(141)371-7288
# Email:martinezanna@example.com
# Site:https://reilly-howell.biz/
#
# Oly | Description | Unit
#
# 5.00 _Two drug data. | 46.98
# 2.00 _Mission federal my. | 7.67
# 3.00 _Defense participant until. | 56.41
# 5.00 Evidence produce. 12.39
#
# Total in words: four hundred and ninet-
# y-eight point zero two
#
# Note:Total payment due in 14 days.
#
# Price
#
# Invoice Date: 06-Jun-2012
#
# Amount
#
# 234.90
# 15.34
# 169.23
# 61.95
#
# TOTAL : 498.02 EUR
#
# Processed Template9_Instance170_resized.jpg, saved text to Template9_Instance170_resized_preprocessed.txt
# Processing original image: Template10_Instance154.jpg
# Text from original image:
# Address:4894 Melanie Pass Apt. 742
# ‘Tammyland, SD 42587 US
#
# Invoice Date: 17-Nov-2017
# Invoice number 7077-628
#
# Mclean-Cochran
# Due Date : 16-Feb-1995
#
# Bill to:Christopher Mayo.
# 87430 Sarah Tunnel Suite 340
#
# East John, MA 84969 US
# Tel:+(878)679-0474
# Email:murphyanthony@example.org
# Site:http:/idiaz.net/
#
#
#
#
#
#
#
# iTems ‘quantry PRICE TAK AMOUNT
# Be large. 400 sat $0.00 $89.24
# ‘Anything exactly hand, 600 © $4095 $0.00 $245.70
#
# DISCOUNT(2.39%): (-) 8.04
#
# TOTAL : 352.03 EUR
#
# Terms & Conditions
# 4. Please sond payment within 8 days of receiving this invoice.
# ‘There will be a 2.5% interest charge per month on late invoices.
# 2. Please include the Invoice number in your payment notes,
#
# Note:
# This order is shipped through blue dart courier
#
# Email:cjames@example.com
#
# Processing preprocessed image: Template10_Instance154_thresholded.jpg
# Text from preprocessed image:
# Address:4894 Melanie Pass Apt. 742
# ‘Tammyland, SD 42587 US
#
# Invoice Date: 17-Nov-2017
#
# Invoice number 7077-628
# Mclean-Cochran
#
# Due Date : 16-Feb-1995
#
#
#
# Bill to:Christopher Mayo
# 87430 Sarah Tunnel Suite 340
#
# East John, MA 84969 US
# Tel:+(878)679-0474
# Email:murphyanthony@example.org
# Site:http:/idiaz.netl
#
# Trews. quanry PRICE TAK ‘AMOUNT
# Be large, 4.00 s2za1 $000 se9.28
# 8.00 sass $000 $245.70
#
# ‘Anything exactly hand,
#
# DISCOUNT(2.39%): (.) 8.01
#
# TOTAL : 352.03 EUR
#
# 1 & Conditions
# 39¢ send payment within 8 days of receiving this invoice.
# ‘There willbe a 2.5% intrest charge per month on lae invoices.
# 2. Pleate include the Invoice number in your payment notes,
#
#
#
#
#
#
#
# Note:
# This order is shipped through blue dart courier
#
# Email:cjames@example.com
#
# Processed Template10_Instance154.jpg, saved text to Template10_Instance154_preprocessed.txt
# Processing original image: Template2_Instance3_resized.jpg
# Text from original image:
# a4
#
# 4
#
# Barnes, Garcia and Martin
#
# Address:13868 Michael Wall
# North Cindytown, CT 45483 US
#
# GSTIN: 331234567891022Z1
#
# Buyer :Tracy Drake
#
# 0864 Michelle Haven Suite 174
#
# Lake Kimberly, WV 26542 US
# Tel:+(770)167-9226
# Email:bobby54@example.org
# Site:http://www.mcfarland-graham.com/
#
# Description QUANTITY
# Share writer real. 2.00
# Rather on entire. 6.00
#
# COMMERCIAL INVOICE
#
# Invoice number 7Y5M6d-853
# Invoice Date: 11-May-2007
#
# | PRICE
# $64.60
# | $5.42
#
# SUB_TOTAL : 161.72 USD
#
# GST(7%) : 11.32
#
# TOTAL : 165.45 USD
#
# Processing preprocessed image: Template2_Instance3_resized_thresholded.jpg
# Text from preprocessed image:
# VW
#
# 4
#
# Barnes, Garcia and Martin
#
# Address:13868 Michael Wall
# North Cindytown, CT 45483 US
#
# GSTIN: 3312345678910221
#
# Buyer :Tracy Drake
#
# 0864 Michelle Haven Suite 174
#
# Lake Kimberly, WV 26542 US
# Tel:+(770)167-9226
# Email:bobby54@example.org
# Site:http:/iwww.mcfarland-graham.com/
#
# Description QUANTITY
# Share writer real. 2.00
# Rather on entire. 6.00
#
# COMMERCIAL INVOICE
#
# Invoice number 7Y5M6d-853
# Invoice Date: 11-May-2007
#
# PRICE
# $64.60
# $5.42
#
# SUB_TOTAL : 161.72 USD
#
# GST(7%) : 11.32
#
# TOTAL : 165.45 USD
#
# Processed Template2_Instance3_resized.jpg, saved text to Template2_Instance3_resized_preprocessed.txt
# Processing original image: Template1_Instance144_resized.jpg
# Text from original image:
# COMMERCIAL INVOICE
#
# Date: 02-May-2018
# Due Date : 03-Dec-2017
#
# PO Number :53
# Address:16424 Timothy Mission Bill to:Sonya Anderson
# Markville, AK 58294 US 34054 Nguyen Pine Apt. 299
# Brownbury, OH 92819 US
# Email:melvin40@example.net Tel:+(787)285-1421
# www.ThompsonandSons.org Email:dennisdecker@example.net
# (GSTIN: 12345670 00070007 Site:http://www.jones.info/
#
# GSTIN: OG@AAMFCO376K124
#
# ITEMS. QUANTITY
# Report his for. 2.00
# Catch. 1.00
#
#
#
# Science else. 1.00
#
# Total in words: one hundred and sevent-
# y-three point seven two
#
# Bank Name State Bank of California
# Branch Name Raf CAMP
#
# Bank Account Number 12970589
#
# Bank Swift Code SBININBB250
#
# Thank you for your business!
#
# SUB_TOTAL : 170.38 USD
#
# DISCOUNT(4.74%): (-) 8.08
# TAX:VAT (3.66%): 6.24 USD
#
# TOTAL : 173.72 USD
#
# Processing preprocessed image: Template1_Instance144_resized_thresholded.jpg
# Text from preprocessed image:
# COMMERCIAL INVOICE
#
# Date: 02-May-2018
# Due Date : 03-Dec-2017
# PO Number :53
#
# Address:16424 Timothy Mission Bill to:Sonya Anderson
#
# Markville, AK 58294 US 34054 Nguyen Pine Apt. 299
# Brownbury, OH 92819 US
#
# Email:melvind0@example.net Tel:+(787)285-1421
#
# www.ThompsonandSons.org Email:dennisdecker@example.net
#
# (GSTIN: 12345670 00070007 Site:http://www.jones.info/
#
# GSTIN: OG@AAMFCO376K124
#
# ITEMS QUANTITY
# Report his for. 2.00
#
# Catch. 1.00
#
#
#
# Science else. 1.00
#
# Total in words: one hundred and sevent-
# y-three point seven two
#
# Bank Name State Bank of California
# Branch Name Raf CAMP
#
# Bank Account Number 12970589
#
# Bank Swift Code SBININBB250
#
# Thank you for your business!
#
# SUB_TOTAL : 170.38 USD
#
# DISCOUNT(4.74%): (-) 8.08
# TAX:VAT (3.66%): 6.24 USD
#
# TOTAL : 173.72 USD
#
# Processed Template1_Instance144_resized.jpg, saved text to Template1_Instance144_resized_preprocessed.txt
# Processing original image: Template2_Instance3.jpg
# Text from original image:
# Af
#
# >
#
# Barnes, Garcia and Martin
#
# Address:13868 Michael Wall
# North Cindytown, CT 45483 US
#
# GSTIN: 3312345678910221
#
# Buyer :Tracy Drake
# 0864 Michelle Haven Suite 174
#
# Lake Kimberly, WV 26542 US
# Tel:+(770)167-9226
# Email:bobby54@example.org
# Site:http://www.mefarland-graham.com!
#
# Description
# ‘Share write eal
#
# Rather on entire,
#
# ‘QUANTITY
# 2.00
# 6.00
#
# COMMERCIAL INVOICE
#
# Invoice number 7Y5M64-853
# Invoice Date: 11-May-2007
#
# PRICE
# 364.60
# $5.42
#
# SUB_TOTAL : 161.72 USD
#
# GST(7%) : 11.32,
#
# TOTAL : 165.45 USD
#
# Processing preprocessed image: Template2_Instance3_thresholded.jpg
# Text from preprocessed image:
# —
#
# Barnes, Garcia and Martin
#
# Address:13868 Michael Wall
# North Cindytown, CT 45483 US
#
# GSTIN: 3312345678910221
#
# Buyer :Tracy Drake
#
# 0864 Michelle Haven Suite 174
#
# Lake Kimberly, WV 26542 US
#
# Tel:+(770)167-9226
#
# Email:bobbyS4@example.org
# ttp:/fwww.mefarland-graham.com!
#
#
#
#
#
# Description
# Share writer rel
#
# Rather on entre.
#
# (QUANTITY
# 200
# 6.00
#
# COMMERCIAL INVOICE
#
# Invoice number 7Y5M6d-853
# Invoice Date: 11-May-2007
#
# PRICE
# $64.60
# $542
#
# SUB_TOTAL : 161.72 USD
#
# @ST(7%) : 11.32
#
# TOTAL : 165.45 USD
#
# Processed Template2_Instance3.jpg, saved text to Template2_Instance3_preprocessed.txt
# Processing original image: Template7_Instance154.jpg
# Text from original image:
# White and Sons
#
# Email:cpetersen@example.com
#
# ‘www.WhiteandSons.org
#
#
#
# COMMERCIAL INVOICE
#
# Bill to:Courtney Boone INVOICE # INV58998208
# 288 Rachel View
#
# East Karen, GU 73094 US Invoice Date: 25-Sep-2000
# Aetss(As6) 545-4976 Due Date : 07-Mar-2010
# Email:uwalter@example.net
# Site:http://bennett info!
#
#
#
#
#
#
#
#
#
#
#
# TEMS (QUANTITY, PRICE
# ‘Opportunity party 6.00 49.62
# Father bring painting 3.00 $52.76
#
#
#
#
#
# ‘SUB_TOTAL : 456.00 USD
#
# GST(9%) : 41.04
#
# TOTAL : 462.77 USD
#
# Processing preprocessed image: Template7_Instance154_thresholded.jpg
# Text from preprocessed image:
#
#
# White and Sons
#
# Email:cpetersen@example.com
#
#
#
# ‘www. WhiteandSons.org
#
# COMMERCIAL INVOICE
#
# Bill to:Courtney Boone
# 288 Rachel View
#
# East Karen, GU 73094 US
# Tel:+(436)546-4376
# Email:uwalter@example.net
# Site:http:/tbennett info!
#
# INVOICE # INV68998208
#
# Invoice Date: 25-Sep-2000
# Due Date : 07-Mar-2010
#
#
#
#
#
#
#
#
#
#
#
# TEMS QUANTITY PRICE
# Opportunity pany. 600 $49.62
# Father bing painting 300 $52.76
#
#
#
# ‘SUB_TOTAL : 456.00 USD
#
# GST(9%) : 41.04
#
# TOTAL : 462.77 USD
#
# Processed Template7_Instance154.jpg, saved text to Template7_Instance154_preprocessed.txt
# Processing original image: Template10_Instance154_resized.jpg
# Text from original image:
# Address:4894 Melanie Pass Apt. 742
# Tammyland, SD 42587 US
#
# Invoice Date: 17-Nov-2017
#
# Invoice number 7077-628
# Mclean-Cochran
#
# Due Date : 16-Feb-1995
#
# Bill to:Christopher Mayo
#
# 87430 Sarah Tunnel Suite 340
#
# East John, MA 84969 US
# Tel:+(878)679-0474
# Email:murphyanthony@example.org
#
# Site:http://diaz.net/
# ITEMS QUANTITY PRICE TAX AMOUNT
# Be large. 4,00 $22.31 $0.00 $89.24
# Anything exactly hand. 6.00 $40.95 $0.00 $245.70
#
# DISCOUNT(2.39%): (-) 8.01
#
# TOTAL : 352.03 EUR
#
# Terms & Conditions
#
# 1. Please send payment within 8 days of receiving this invoice.
# There will be a 2.5% interest charge per month on late invoices.
# 2. Please include the Invoice number in your payment notes.
#
# Note:
# This order is shipped through blue dart courier
#
# Email:cjames@example.com
#
# Processing preprocessed image: Template10_Instance154_resized_thresholded.jpg
# Text from preprocessed image:
# Address:4894 Melanie Pass Apt. 742
# Tammyland, SD 42587 US
#
# Invoice Date: 17-Nov-2017
# Invoice number 7077-628
#
# Mclean-Cochran
# Due Date : 16-Feb-1995
#
#
#
# Bill to:Christopher Mayo
#
# 87430 Sarah Tunnel Suite 340
#
# East John, MA 84969 US
# Tel:+(878)679-0474
# Email:murphyanthony@example.org
# Site:http://diaz.net/
#
# ITEMS QUANTITY PRICE TAX AMOUNT
# Be large. 4.00 $22.31 $0.00 $89.24
# Anything exactly hand 6.00 $40.95 $0.00 $245.70
#
# DISCOUNT(2.39%): (-) 8.01
#
# TOTAL : 352.03 EUR
#
# Terms & Conditions
#
# 1. Please send payment within 8 days of receiving this invoice.
# There will be a 2.5% interest charge per month on late invoices.
# 2. Please include the invoice number in your payment notes.
#
# Note:
# This order is shipped through blue dart courier
#
# Email:cjames@example.com
#
# Processed Template10_Instance154_resized.jpg, saved text to Template10_Instance154_resized_preprocessed.txt
# Processing original image: Template9_Instance170.jpg
# Text from original image:
# Navarro, Ford and Bryan
#
# GSTINIUIN: 09AABCS142961ZS
#
# Email:rclark@example.org
# Buyer :Alan Poole
#
# 515 Suzanne Dam Suite 983
#
# Brittanyside, OH 05404 US
# Tel:+(141)371-7288
# Email:martinezanna@example.com
# Sitezhttps://relly-howell.biz!
#
#
#
# INVOICE # INV/73-81/333
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Amount —_|
#
# 234,90 |
#
# te 15.34
#
# Defense participant until. | 56.41 169.23 |
# Evidence produce. 12 61.95 |
#
#
#
# Total in words: four hundred and ninet-
# y-eight point zero two
#
# Note:Total payment due in 14 days.
#
#
#
# TOTAL : 498.02 EUR
#
# Processing preprocessed image: Template9_Instance170_thresholded.jpg
# Text from preprocessed image:
# Navarro, Ford and Bryan INVOICE # INVI73-81/333
#
# GSTINIUIN: 09AABCS142961ZS
#
# Email:rclark@example.org
# Buyer :Alan Poole
#
# 515 Suzanne Dam Suite 983
#
# Brittanyside, OH 05404 US
# Tel:+(141)371-7288
# Email:martinezanna@example.com
# Sitezhttps:ifreilly-howell.biz/
#
# 5.00 Two drug data, 46.98
#
# 2.00 Mission federal my. 7.87
# 3.00 Defense participant until 56.41
# 5.00 Evidence produce. 12.39
#
# Total in words: four hundred and ninet-
# y-eight point zero two
#
# Note:Total payment due in 14 days.
#
# Invoice Date: 06-Jun-2012
#
# 234.90
# 15.34
# 169.23
# 61.95
#
# TOTAL : 498.02 EUR
#
# Processed Template9_Instance170.jpg, saved text to Template9_Instance170_preprocessed.txt
# Processing original image: Template1_Instance144.jpg
# Text from original image:
# Address:16424 Timothy Mission
# Markville, AK 58294 US
#
# Email:melvindo@example.net
# ‘www.ThompsonandSons.org
# (GSTIN: 12345670 00070007
#
#
#
# COMMERCIAL INVOICE
#
# Date: 02-May-2018
# Due Date : 03-Dec-2017
# PO Number :53
#
#
#
# Bill to:Sonya Anderson
# 34054 Nguyen Pine Apt. 299
# Brownbury, OH 92819 US
# Tol:+(787)285-1421
# Email:dennisdecker@example.net
# Site:http://wwwjones.info!
#
# GSTIN: OG@AAMFCO376K124
#
#
#
#
#
#
#
#
#
#
#
# TEMS (QUANTITY, PRICE:
# Report his for. 2.00 5358
#
# Catch, 100 $83.22
# ‘Science ose 100 $80.00
#
#
#
#
#
#
#
#
#
# Total in words:
# y-three point seven two.
# Bank Name
#
# Branch Name Raf CAMP.
# Bank Account Number 12970589
# Bank Swift Code SBININBB250
#
#
#
# ‘Thank you for your business!
#
# ‘State Bank of California
#
# ‘one hundred and sevent-
#
# ‘SUB_TOTAL : 170.38 USD
# DISCOUNT(4.74%): (-) 8.08
# TAX:VAT (3.66%): 6.24 USD
#
#
#
# TOTAL : 173.72 USD
#
# Processing preprocessed image: Template1_Instance144_thresholded.jpg
# Text from preprocessed image:
# Address:16424 Timothy Mission
# Markville, AK 58294 US
#
# Email:melvingo@example.net
# ‘www. ThompsonandSons.org
# (GSTIN: 12345670 00070007
#
# COMMERCIAL INVOICE
#
# Date: 02-May-2018
# Due Date : 03-Dec-2017
# PO Number 53
#
# Bill to:Sonya Anderson
# 34054 Nguyen Pine Apt. 299
# Brownbury, OH 92819 US.
# Tol:+(787)285-1421
# Email:dennisdecker@example.net
# Site:http://www jones.info!
#
# GSTIN: OG@AAMFCOSTK124
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TEMS ‘QUANTITY PRICE
# Report his fo 200 $3.58
#
# Galen, 1.00 309.22
# Science eis. 1.00 $80.00
#
#
#
# Total in words: one hundred and sevent-
# y-three point seven two
#
# Bank Name State Bank of California
# Branch Name Raf CAMP.
#
# Bank Account Number 12970589
#
# Bank Swift Code SBININBB250
#
# ‘Thank you for your business!
#
# ‘SUB_TOTAL : 170.38 USD
# DISCOUNT(4.74%): () 8.08
# TAK:VAT (3.68%): 6.24USD
#
#
#
#
#
# TOTAL: 173.72 USD
#
#
#
# Processed Template1_Instance144.jpg, saved text to Template1_Instance144_preprocessed.txt
# Processing original image: Template7_Instance154_resized.jpg
# Text from original image:
# White and Sons
#
# Email:cpetersen@example.com
#
#
#
# www.WhiteandSons.org
#
# COMMERCIAL INVOICE
#
# Bill to:Courtney Boone INVOICE # INV58998208
# 288 Rachel View
#
# East Karen, GU 73094 US Invoice Date: 25-Sep-2000
# Tel:s(Q36)546-4978 Due Date : 07-Mar-2010
#
# Email:uwalter@example.net
# Site:http://bennett.info/
#
# QUANTITY
# prey pry. [60 SiC
#
#
#
# Father bring painting, Se
#
# SUB_TOTAL : 456.00 USD
#
# GST(9%) : 41.04
#
# TOTAL : 462.77 USD
#
# Processing preprocessed image: Template7_Instance154_resized_thresholded.jpg
# Text from preprocessed image:
# White and Sons
#
# Email:cpetersen@example.com
#
#
#
# www.WhiteandSons.org
#
# COMMERCIAL INVOICE
#
# Bill to:Courtney Boone INVOICE # INV58998208
# 288 Rachel View
#
# East Karen, GU 73094 US Invoice Date: 25-Sep-2000
# Lett (ASG) SSS4516 Due Date : 07-Mar-2010
#
# Email:uwalter@example.net
# Site:http://bennett.info/
#
# ITEMS QUANTITY
#
#
#
# Opportunity party 6.00
#
#
#
#
#
# Father bring painting. 3.00
#
# SUB_TOTAL : 456.00 USD
#
# GST(9%) : 41.04
#
# TOTAL : 462.77 USD
#
# Processed Template7_Instance154_resized.jpg, saved text to Template7_Instance154_resized_preprocessed.txt
# Processing original image: Template6_Instance170.jpg
# Text from original image:
# INVOICE
#
# Phillips, Thomas and Malone |
#
# Bill to:Rita Martinez
# 743 Kerr Vista
# Howardfort, 1A 57845 US
#
#
#
#
#
# INVOICE # INV95313560,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tel:+(432)825-1664 Date: 17-Oct-1993
# Email:guzmanstephanie@example.org PO Number 82
# Site:https://howard.com/
#
# ‘ty 0 Description Unitprice | Amount
# 5.00 322241 | Animal much righ bition, 53.20 266.00
# 100) 1829633 __| Different American yet 2041 2041
# 3.00 110699__| Bad bag product. 672 20.16
# 4.00 aera? _| Cour 2044 32176
#
#
#
#
#
#
#
# Note: All payments to be made in cash.
# Contact us for queries on these quotations.
#
# ‘SUB_TOTAL : 628.33 EUR
#
# TAX:VAT (3.03%): 19.03 EUR
#
# TOTAL : 638.06 EUR
#
#
#
# Processing preprocessed image: Template6_Instance170_thresholded.jpg
# Text from preprocessed image:
# INVOICE
#
# Phillips, Thomas and Malone
#
# Bill to:Rita Martinez.
# 743 Kerr Vista
#
# Howardfort, 1A 57845 US
# Tel:+(432)625-1664
# Email:guzmanstephanie@example.org
# Site:https:i/howard.com!
#
#
#
# INVOICE # INV95313560,
# Date: 17-Oct-1993
# PO Number 82
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Qty 0 Description Unitprice | Amount
# 5.00 32224) __| Animal much righ ion, 53.20 266.00
# 1.00 29633 __| Different American yet. 20.84 2041
#
# 300 110689 __| Bad bag product, 672 20.16
# 4.00 aera? | Coun, eae 32176
#
#
#
#
#
# Note: All payments to be made in cash.
# Contact us for queries on these quotations.
#
# SUB_TOTAL : 628.33 EUR
#
# TAXVAT (3.03%)
#
#
#
# 19.03 EUR
#
# TOTAL : 638.08 EUR
#
#
#
# Processed Template6_Instance170.jpg, saved text to Template6_Instance170_preprocessed.txt
